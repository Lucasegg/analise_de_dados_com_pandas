# %%
#criando uma  lista
animais=[1, 2, 3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro", "gato", 12345, 0.9]
animais
# Out:
# ['cachorro', 'gato', 12345, 0.9]

# %%
animais[0]
# Out:
# 'cachorro'

# %%
animais[3]
# Out:
# 0.9

# %%
#substituindo
animais[0] = "papagaio"

# %%
animais
# Out:
# ['papagaio', 'gato', 12345, 0.9]

# %%
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 0.9]

# %%
len(animais)
# Out:
# 3

# %%
"gato" is animais
#não tem gato na lista
# Out:
# False

# %%
lista = [500, 30, 100, 80, 10]
lista
# Out:
# [500, 30, 100, 80, 10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leao")
animais
# Out:
# ['papagaio', 12345, 0.9, 'leao']

# %%
animais.extend(["cobra", 6])

# %%
animais
# Out:
# ['papagaio', 12345, 0.9, 'leao', 'cobra', 6]

# %%
animais.count("cachorro")
# Out:
# 0

# %%
animais
# Out:
# ['papagaio', 12345, 0.9, 'leao', 'cobra', 6]

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 100, 500]

# %%
#Tuplas

# %%
tp = ("Banana", "Maçã", 10, 50)
tp
# Out:
# ('Banana', 'Maçã', 10, 50)

# %%
tp[0]
# Out:
# 'Banana'

# %%
tp[0] = "Laranja"
#Tuplas são Imutáveis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-37f4fcd7b828> in <module>()
# ----> 1 tp[0] = "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("Maçã")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maçã')

# %%
#Dicionários
#Dicionários utilizam {}

# %%
dc = {"Maçã":20, "Banana":10, "Laranja":15, "Uva":5}
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Maçã': 20, 'Uva': 5}

# %%
dc["Maçã"]
# Out:
# 20

# %%
dc["Maçã"] = 20

# %%
dc["Maçã"] = 25
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Maçã': 25, 'Uva': 5}

# %%
dc.keys()
# Out:
# dict_keys(['Maçã', 'Banana', 'Laranja', 'Uva'])

# %%
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
dc.setdefault("Limão", 22)
# Out:
# 22

# %%
dc
# Out:
# {'Banana': 10, 'Laranja': 15, 'Limão': 22, 'Maçã': 25, 'Uva': 5}
